# %%
import pandas as pd
from pathlib import Path

# notebooks/ 또는 프로젝트 루트 어디서 실행해도 data/ 폴더를 자동으로 찾음
_cwd = Path.cwd()
DATA_DIR = _cwd / 'data' if (_cwd / 'data').exists() else _cwd.parent / 'data'
print(f"데이터 경로: {DATA_DIR}")

print("데이터를 불러오는 중입니다... 잠시만 기다려주세요.")

orders      = pd.read_csv(DATA_DIR / 'orders.csv')
prior       = pd.read_csv(DATA_DIR / 'order_products__prior.csv')
train       = pd.read_csv(DATA_DIR / 'order_products__train.csv')
products    = pd.read_csv(DATA_DIR / 'products.csv')
aisles      = pd.read_csv(DATA_DIR / 'aisles.csv')
departments = pd.read_csv(DATA_DIR / 'departments.csv')

print("데이터 로드 완료")
